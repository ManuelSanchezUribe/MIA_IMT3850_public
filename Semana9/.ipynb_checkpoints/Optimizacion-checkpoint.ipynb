# %% [markdown]
# <hr style="border:1px solid #FEC60D"> </hr>
# <center><h1 style="color:#173F8A;"> FUNDAMENTOS MATEMATICOS PARA INTELIGENCIA ARTIFICIAL</h1></center>
# <center><h1 style="color:#173F8A;"> IMT 3850, 2023 </h1></center>
# <hr style="border:1px solid #FEC60D"> </hr>
# <center><h3 style="color:#0176DE;text-align:right;"> Profesor. Manuel A. Sanchez<br></h3></center>
# <h3 style="color:#03122E;text-align:right;"> Magister en Inteligencia Artificial - MIA <br> Instituto de Ingenieria Matematica y Computacional - IMC<br>  Pontificia Universidad Catolica de Chile<br>   </h3>
#
#
#
#
# <!-- Palette colors UC:
# Primaria:
# celeste:#0176DE, azul #173F8A, azul oscuro: #03122E, amarillo: #FEC60D, amarillo oscuro: #E3AE00
# Secundaria
# gris oscuro: #707070
# -->

# %% [markdown]
# <hr style="border:2px solid #03122E"> </hr>
# <center><h1 style="color:#173F8A;"> Optimizacion - clase 7</h1></center>
# <hr style="border:2px solid #03122E"> </hr>

# %%
import matplotlib.pyplot as plt
import matplotlib.colors
from IPython.display import display, HTML
display(HTML("""<style>.output {display: flex;align-items: center;text-align: center;}</style>"""))
# Out:
# <style>.output {display: flex;align-items: center;text-align: center;}</style>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Ejemplo: minimos
# \begin{equation}
# f(x) = x^4 + 7x^3 + 5 x^{2} -12 x+3
# \end{equation}

# %%
f = lambda x: x**4 + 7*x**3 + 5*x**2 - 17*x + 3
x = np.linspace(-6,2,100)
plt.plot(x, f(x))
plt.show()

# %% [markdown]
# ## Funciones convexas

# %% [markdown]
# ### Ejemplo 1: $f(x) = 3x^{2} - 5x + 2$

# %%
fcon1 = lambda x: 3*x**2-5*x+2
x = np.linspace(-3,3,100)
plt.plot(x,fcon1(x))
plt.show()

# %% [markdown]
# ### Ejemplo 2: $ f(x) = x\log_2(x)$

# %%
fcon2 = lambda x: x*np.log2(x)
x = np.linspace(0.001,3,100)
plt.plot(x,fcon2(x))
plt.show()

# %% [markdown]
# ### Ejemplo 3: $f(x) = \ln(1+\exp(x))$

# %%
fcon3 = lambda x: np.log(1+np.exp(x))
x = np.linspace(-3,3,100)
plt.plot(x,fcon3(x))
plt.show()

# %% [markdown]
# ## Ejemplo: Newton

# %%
F = lambda x: 1/3*x**3 - 4*x
gradF = lambda x: x**2 - 4
H = lambda x: 2*x

# Newton:
def Newton_iter(x0, gradF_x0, H_x0):
    if np.isscalar(x0)==1:
        return x0 - gradF_x0/H_x0
    else:
        return x0 - np.linalg.solve(H_x0, gradF_x0)
    
x0 = -2.5
#  iteracion 1
x1 = Newton_iter(x0, gradF(x0), H(x0))
#  iteracion 2
x2 = Newton_iter(x1, gradF(x1), H(x1))
#  iteracion 3
x3 = Newton_iter(x2, gradF(x2), H(x2))
print(x3)
#xplot = np.linspace(1.8,2.5,100)
xplot = np.linspace(-2.5,-1.8,100)

fig, ax = plt.subplots(1,2 , figsize=(14,6))
ax[0].plot(xplot, F(xplot))
ax[0].plot(x0,F(x0),'.',label='x0', markersize=20)
ax[0].plot(x1,F(x1),'.',label='x1', markersize=20)
ax[0].plot(x2,F(x2),'.',label='x2', markersize=20)
ax[0].plot(x3,F(x3),'.',label='x3', markersize=20)
ax[0].legend()


xzoom = np.linspace(1.9999,2.001,100)
ax[1].plot(xzoom, F(xzoom))
ax[1].plot(x2,F(x2),'.',color='C03',label='x2', markersize=20)
ax[1].plot(x3,F(x3),'.',color='C04', label='x3', markersize=20)
ax[1].legend()
plt.show()
# Out:
# -2.0000000929222947

# %% [markdown]
# ## Multiplicadores de Lagrange

# %%
circle2 = plt.Circle((0, 0), 1, color='b', fill=False)
ax = plt.gca()

a_1 =1
a_2 = 2
m = -a_1/a_2

# change default range so that new circles will work
ax.set_xlim((-1.5, 1.5))
ax.set_ylim((-1.5, 1.5))

ax.plot([])
    
ax.add_patch(circle2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución Gaussiana
mu = 1  # Media
sigma = 0.5  # Desviación estándar

# Definir el rango de valores x
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

# Calcular la función de densidad de probabilidad (pdf)
pdf = norm.pdf(x, mu, sigma)

# Dibujar la función de densidad de probabilidad
plt.plot(x, pdf, 'k-', linewidth=2)

# Rellenar el área bajo la curva
plt.fill_between(x, pdf, color='lightgray')

# Configuración de la trama
plt.title('Distribución Gaussiana')
plt.xlabel('x')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)

# Mostrar el gráfico

plt.savefig('gaussiana.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parámetros de la distribución Gaussiana
mu = 1  # Media
sigma = 0.5  # Desviación estándar

# Definir el rango de valores x
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

# Calcular la función de densidad de probabilidad (pdf)
pdf = norm.pdf(x, mu, sigma)

# Dibujar la función de densidad de probabilidad
plt.plot(x, pdf, 'k-', linewidth=2)

# Rellenar el área bajo la curva entre mu - sigma y mu + sigma
plt.fill_between(x, pdf, where=(x >= mu - sigma) & (x <= mu + sigma), color='lightgray')

# Configuración de la trama
plt.title('Distribución Gaussiana')
plt.xlabel('x')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)

# Mostrar el gráfico

plt.savefig('gaussianasigma.png')
plt.show()
